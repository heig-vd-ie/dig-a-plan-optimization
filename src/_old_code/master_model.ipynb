# %%
import pandapower as pp
import pandas as pd
import numpy as np
import pyomo.environ as pyo

from master_model_S import master_model
from slave_model_S import slave_model_candidate_indexed
from slave_model.sets import slave_model_sets
from slave_model.constraints import slave_model_constraints
from slave_model.parameters import slave_model_parameters
from slave_model.variables import slave_model_variables
from master_model.sets import master_model_sets
from master_model.constraints import master_model_constraints
from master_model.parameters import master_model_parameters
from master_model.variables import master_model_variables
import polars as pl
from polars import col as c
from general_function import pl_to_dict
from polars_function import list_to_list_of_tuple

from dig_a_plan_pipeline import DigAPlan

# %%
# -------------------------
# Global Connectivity Dictionary for Instance Data.
# -------------------------
# F_instance provides two candidate pairs for each branch.
F_instance = {
    0: [(0, 1), (1, 0)],
    1: [(1, 2), (2, 1)],
    2: [(1, 3), (3, 1)],
    3: [(2, 4), (4, 2)],
    4: [(2, 5), (5, 2)],
    5: [(5, 6), (6, 5)],
    6: [(3, 6), (6, 3)],
    7: [(4, 7), (7, 4)],
    8: [(6, 7), (7, 6)]
}



# -------------------------
# (A) Create the pandapower network.
# -------------------------
def create_pandapower_net():
    net = pp.create_empty_network()
    for i in range(8):
        pp.create_bus(net, vn_kv=20, name=f"bus_{i}")
    pp.create_ext_grid(net, bus=0, vm_pu=1.0, name="Grid Connection")
    
    p_load_dict = {0: 0.0, 1: 0.1, 2: 0.12, 3: 0.15, 4: 0.08, 5: 0.1, 6: 0.12, 7: 0.06}
    q_load_dict = {0: 0.0, 1: 0.03, 2: 0.04, 3: 0.05, 4: 0.02, 5: 0.03, 6: 0.04, 7: 0.02}
    # Global line parameters.
    r_dict = {1: 0.02, 2: 0.02, 3: 0.03, 4: 0.03, 5: 0.01, 6: 0.02, 7: 0.02, 8: 0.04}
    x_dict = {1: 0.04, 2: 0.04, 3: 0.05, 4: 0.05, 5: 0.02, 6: 0.03, 7: 0.03, 8: 0.06}
    for bus in p_load_dict:
        p = p_load_dict[bus]
        q = q_load_dict[bus]
        if p > 0:
            pp.create_load(net, bus=bus, p_mw=p, q_mvar=q, name=f"load_{bus}")
    
    # For each branch l, use the first candidate of F_instance for network topology.
    for l in sorted(F_instance.keys()):
        from_bus, to_bus = F_instance[l][0]  # Use first candidate for creating the network.
        pp.create_line_from_parameters(
            net,
            from_bus=from_bus,
            to_bus=to_bus,
            length_km=1.0,
            r_ohm_per_km=r_dict.get(l, 0.01),
            x_ohm_per_km=x_dict.get(l, 0.05),
            c_nf_per_km=0.0,
            max_i_ka=1.0,
            name=f"line_{l}"
        )
    
    switchable_keys = [1, 2, 3, 4, 5, 6, 7, 8]
    for key in switchable_keys:
        mask = net.line["name"] == f"line_{key}"
        if mask.sum() == 0:
            raise KeyError(f"No line found with name 'line_{key}'")
        line_idx = net.line.index[mask][0]
        line = net.line.loc[line_idx]
        pp.create_switch(
            net, bus=line["from_bus"], element=line_idx, et="l",
            closed=True, type="CB", name=f"switch_{key}")
    
    pp.create_sgen(net, bus=1, p_mw=0.0, q_mvar=0.0, name="dummy_sgen")
    if net.trafo.empty:
        dummy_trafo = {
            "hv_bus": 0,
            "lv_bus": 1,
            "sn_mva": 0.001,
            "vn_hv_kv": 20,
            "vn_lv_kv": 20,
            "vk_percent": 10.0,
            "vkr_percent": 5.0,
            "i0_percent": 0.0,
            "pfe_kw": 0.0,
            "name": "dummy_trafo"
        }
        net.trafo = pd.DataFrame([dummy_trafo])
    return net

# %%
net = create_pandapower_net()

C_instance =  pl_to_dict(
    pl.from_pandas(net.line.reset_index())
    .select(
        c("index"), 
        pl.concat_list("from_bus", "to_bus").pipe(list_to_list_of_tuple)
        )
    )

# %%
# -------------------------
# (B) Build and Solve the Master Model.
# -------------------------
# Build instance data for the master model.
instance_data_master = {
    None: {
        'N': {None: list(net.bus.index)},
        'L': {None: list(net.line.index)},
        # For the master, we provide F as a single candidate per branch.
        'C': C_instance,
        # S: set of switchable lines.
        'S': {None: [i for i in net.line.index if int(net.line.loc[i, "name"].split("_")[1]) in [1,2,3,4,5,6,7,8]]},
        'r': { i: net.line.loc[i, "r_ohm_per_km"] for i in net.line.index },
        'x': { i: net.line.loc[i, "x_ohm_per_km"] for i in net.line.index },
        'p_node': {0: 0.0, 1: 0.1, 2: 0.12, 3: 0.15, 4: 0.08, 5: 0.1, 6: 0.12, 7: 0.06},
        'q_node': {0: 0.0, 1: 0.03, 2: 0.04, 3: 0.05, 4: 0.02, 5: 0.03, 6: 0.04, 7: 0.02},
        'M': {None: 1e4},
    }
}



master_model: pyo.AbstractModel = pyo.AbstractModel() # type : ignore
master_model = master_model_sets(master_model)
master_model = master_model_parameters(master_model)
master_model = master_model_variables(master_model)
master_model = master_model_constraints(master_model)


# Now create the instance with the instance data.
master_instance = master_model.create_instance(instance_data_master)

# Use your preferred solver; here we use gurobi.
solver = pyo.SolverFactory('gurobi')
# For nonconvex problems, you might need to set options (if applicable).
solver.options['NonConvex'] = 2

results_master = solver.solve(master_instance, tee=True)

print("Master Model Solution:")
# Display selected decision variables.
print("Orientation decisions (d):")
master_instance.d.display()

print("Switch status for switchable lines (Delta):")
master_instance.Delta.display()
# Out:
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO Read LP format model from file /tmp/tmph5pglcgp.pyomo.lp
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO Reading time = 0.00 seconds
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO x1: 66 rows, 35 columns, 132 nonzeros
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO Set parameter NonConvex to value 2
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 24.04.1 LTS")
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO CPU model: Intel(R) Core(TM) i7-4790 CPU @ 3.60GHz, instruction set [SSE2|AVX|AVX2]
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO Non-default parameters:
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO NonConvex  2
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO Optimize a model with 66 rows, 35 columns and 132 nonzeros
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO Model fingerprint: 0xd097c1df
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO Model has 18 quadratic objective terms
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO Variable types: 18 continuous, 17 integer (17 binary)
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO Coefficient statistics:
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO   Matrix range     [1e+00, 1e+04]
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO   Objective range  [0e+00, 0e+00]
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO   QObjective range [2e-02, 8e-02]
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO   Bounds range     [1e+00, 1e+00]
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO   RHS range        [2e-02, 1e+00]
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO Found heuristic solution: objective 0.0147350
# Read LP format model from file /tmp/tmph5pglcgp.pyomo.lp
# Reading time = 0.00 seconds
# x1: 66 rows, 35 columns, 132 nonzeros
# Set parameter NonConvex to value 2
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 24.04.1 LTS")
#
# CPU model: Intel(R) Core(TM) i7-4790 CPU @ 3.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# NonConvex  2
#
# Optimize a model with 66 rows, 35 columns and 132 nonzeros
# Model fingerprint: 0xd097c1df
# Model has 18 quadratic objective terms
# Variable types: 18 continuous, 17 integer (17 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e-02, 8e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-02, 1e+00]
# Found heuristic solution: objective 0.0147350
# Presolve removed 52 rows and 21 columns
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO Presolve removed 52 rows and 21 columns
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO Presolve time: 0.00s
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO Presolved: 14 rows, 14 columns, 34 nonzeros
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO Presolved model has 12 quadratic objective terms
# Presolve time: 0.00s
# Presolved: 14 rows, 14 columns, 34 nonzeros
# Presolved model has 12 quadratic objective terms
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO Variable types: 12 continuous, 2 integer (2 binary)
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO Root relaxation: objective 1.160213e-02, 25 iterations, 0.00 seconds (0.00 work units)
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO     Nodes    |    Current Node    |     Objective Bounds      |     Work
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# 2025-04-15 16:06:50 B01BPC06 gurobipy[2599273] INFO
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO      0     0    0.01160    0    2    0.01474    0.01160  21.3%     -    0s
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO H    0     0                       0.0116510    0.01160  0.42%     -    0s
# Variable types: 12 continuous, 2 integer (2 binary)
#
# Root relaxation: objective 1.160213e-02, 25 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.01160    0    2    0.01474    0.01160  21.3%     -    0s
# H    0     0                       0.0116510    0.01160  0.42%     -    0s
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Explored 1 nodes (25 simplex iterations) in 0.04 seconds (0.00 work units)
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Thread count was 8 (of 8 available processors)
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Solution count 2: 0.011651 0.014735
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Optimal solution found (tolerance 1.00e-04)
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Best objective 1.165100000002e-02, best bound 1.165100000002e-02, gap 0.0000%
#
# Explored 1 nodes (25 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.011651 0.014735
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.165100000002e-02, best bound 1.165100000002e-02, gap 0.0000%
# Master Model Solution:
# Orientation decisions (d):
# d : Size=9, Index=LC
#     Key       : Lower : Value : Upper : Fixed : Stale : Domain
#     (0, 0, 1) :     0 :   1.0 :     1 : False : False : Binary
#     (1, 1, 2) :     0 :   1.0 :     1 : False : False : Binary
#     (2, 1, 3) :     0 :   1.0 :     1 : False : False : Binary
#     (3, 2, 4) :     0 :   1.0 :     1 : False : False : Binary
#     (4, 2, 5) :     0 :   1.0 :     1 : False : False : Binary
#     (5, 5, 6) :     0 :   0.0 :     1 : False : False : Binary
#     (6, 3, 6) :     0 :   1.0 :     1 : False : False : Binary
#     (7, 4, 7) :     0 :   0.0 :     1 : False : False : Binary
#     (8, 6, 7) :     0 :   1.0 :     1 : False : False : Binary
# Switch status for switchable lines (Delta):
# Delta : Size=8, Index=S
#     Key : Lower : Value : Upper : Fixed : Stale : Domain
#       1 :     0 :   1.0 :     1 : False : False : Binary
#       2 :     0 :   1.0 :     1 : False : False : Binary
#       3 :     0 :   1.0 :     1 : False : False : Binary
#       4 :     0 :   1.0 :     1 : False : False : Binary
#       5 :     0 :   0.0 :     1 : False : False : Binary
#       6 :     0 :   1.0 :     1 : False : False : Binary
#       7 :     0 :   0.0 :     1 : False : False : Binary
#       8 :     0 :   1.0 :     1 : False : False : Binary

# %%
master_instance.d.extract_values()
# Out:
# {(0, 0, 1): 1.0,
#  (1, 1, 2): 1.0,
#  (2, 1, 3): 1.0,
#  (3, 2, 4): 1.0,
#  (4, 2, 5): 1.0,
#  (5, 5, 6): 0.0,
#  (6, 3, 6): 1.0,
#  (7, 4, 7): 0.0,
#  (8, 6, 7): 1.0}

# %%
C_instance =  pl_to_dict(
    pl.from_pandas(net.line.reset_index())
    .select(
        c("index"), 
        pl.concat_list("from_bus", "to_bus").pipe(list_to_list_of_tuple)
        )
    )


# Now, build the instance data dictionary for the slave model.
# Here we do not supply separate parent and child because the candidate-based model uses F.
instance_data_slave = {
    None: {
        'N': {None: list(net.bus.index)},
        'L': {None: list(net.line.index)},
        # For connectivity, we now supply F as the full candidate list for each branch.
        'C': C_instance,
        # Electrical parameters.
        'r': { i: net.line.loc[i, "r_ohm_per_km"] for i in net.line.index },
        'x': { i: net.line.loc[i, "x_ohm_per_km"] for i in net.line.index },
        'b': { i: 0.05 for i in net.line.index},
        # Loads (here using the same as in master instance)
        'p_node': {0: 0.0, 1: 0.1, 2: 0.12, 3: 0.15, 4: 0.08, 5: 0.1, 6: 0.12, 7: 0.06},
        'q_node': {0: 0.0, 1: 0.03, 2: 0.04, 3: 0.05, 4: 0.02, 5: 0.03, 6: 0.04, 7: 0.02},
        'M': {None: 1e4},
        # 'vmin': {None: 0.9},
        # 'vmax': {None: 1.1},
        # Pass the master branch activation decisions from the master model over the candidate set.
        'master_d': master_instance.d.extract_values() 
    }
}

# Now, create and solve the slave model.
solver = pyo.SolverFactory('gurobi')
solver.options['NonConvex'] = 2

# grid_data: dict[str, pl.DataFrame] = {"node_data": pl.DataFrame(), "edge_data": pl.DataFrame()}

# dig_a_plan: DigAPlan = DigAPlan()
# dig_a_plan.add_grid_data(**grid_data)

slave_model: pyo.AbstractModel = pyo.AbstractModel() # type : ignore
slave_model = slave_model_sets(slave_model)
slave_model = slave_model_parameters(slave_model)
slave_model = slave_model_variables(slave_model)
slave_model = slave_model_constraints(slave_model)

slave_instance = slave_model.create_instance(instance_data_slave)
results_slave = solver.solve(slave_instance, tee=True)

print("Slave model solution:")
# slave_instance.display()


slave_instance.p_z_up.display()
slave_instance.p_z_dn.display()
slave_instance.i_sq.display()

slave_instance.q_z_up.display()
slave_instance.q_z_dn.display()
# Out:
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Read LP format model from file /tmp/tmpm0mldcx5.pyomo.lp
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Reading time = 0.00 seconds
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO x1: 161 rows, 99 columns, 360 nonzeros
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Set parameter NonConvex to value 2
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 24.04.1 LTS")
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO CPU model: Intel(R) Core(TM) i7-4790 CPU @ 3.60GHz, instruction set [SSE2|AVX|AVX2]
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Non-default parameters:
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO NonConvex  2
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Optimize a model with 161 rows, 99 columns and 360 nonzeros
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Model fingerprint: 0x558f0e28
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Model has 18 quadratic constraints
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Coefficient statistics:
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO   Matrix range     [5e-04, 1e+00]
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO   QMatrix range    [4e+00, 4e+00]
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO   Objective range  [1e+00, 1e+00]
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO   Bounds range     [1e+00, 1e+00]
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO   RHS range        [2e-02, 1e+08]
# Read LP format model from file /tmp/tmpm0mldcx5.pyomo.lp
# Reading time = 0.00 seconds
# x1: 161 rows, 99 columns, 360 nonzeros
# Set parameter NonConvex to value 2
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 24.04.1 LTS")
#
# CPU model: Intel(R) Core(TM) i7-4790 CPU @ 3.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# NonConvex  2
#
# Optimize a model with 161 rows, 99 columns and 360 nonzeros
# Model fingerprint: 0x558f0e28
# Model has 18 quadratic constraints
# Coefficient statistics:
#   Matrix range     [5e-04, 1e+00]
#   QMatrix range    [4e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-02, 1e+08]
# Presolve removed 132 rows and 63 columns
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Presolve removed 132 rows and 63 columns
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Presolve time: 0.01s
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Presolved: 43 rows, 50 columns, 137 nonzeros
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Presolved model has 7 second-order cone constraints
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Ordering time: 0.00s
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Barrier statistics:
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO  Free vars  : 6
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO  AA' NZ     : 1.820e+02
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO  Factor NZ  : 4.180e+02
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO  Factor Ops : 4.922e+03 (less than 1 second per iteration)
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO  Threads    : 1
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO                   Objective                Residual
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Iter       Primal          Dual         Primal    Dual     Compl     Time
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO    0   1.00000000e+00 -9.99999923e+06  1.61e+06 1.00e-01  2.80e+05     0s
# Presolve time: 0.01s
# Presolved: 43 rows, 50 columns, 137 nonzeros
# Presolved model has 7 second-order cone constraints
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 6
#  AA' NZ     : 1.820e+02
#  Factor NZ  : 4.180e+02
#  Factor Ops : 4.922e+03 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.00000000e+00 -9.99999923e+06  1.61e+06 1.00e-01  2.80e+05     0s
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO    1   1.00000000e+00 -1.12757200e+06  1.48e+05 1.44e-01  2.85e+04     0s
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO    2   1.00000000e+00 -2.24021285e+03  2.12e+04 1.32e-01  1.22e+03     0s
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO    3   1.00000000e+00 -1.52959369e+01  5.78e+02 3.10e-02  3.24e+01     0s
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO    4   1.00000000e+00 -1.01438094e+00  1.28e+00 4.80e-04  1.07e-01     0s
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO    5   1.00000000e+00  6.79472215e-01  1.75e-01 2.08e-05  1.35e-02     0s
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO    6   1.00000000e+00  9.18623916e-01  1.92e-07 7.68e-07  1.45e-03     0s
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO    7   1.00000000e+00  9.99883941e-01  6.33e-11 8.95e-10  2.07e-06     0s
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO    8   1.00000000e+00  9.99999872e-01  6.36e-14 9.84e-13  2.28e-09     0s
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Barrier solved model in 8 iterations and 0.03 seconds (0.00 work units)
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO Optimal objective 1.00000000e+00
# 2025-04-15 16:06:51 B01BPC06 gurobipy[2599273] INFO
#    1   1.00000000e+00 -1.12757200e+06  1.48e+05 1.44e-01  2.85e+04     0s
#    2   1.00000000e+00 -2.24021285e+03  2.12e+04 1.32e-01  1.22e+03     0s
#    3   1.00000000e+00 -1.52959369e+01  5.78e+02 3.10e-02  3.24e+01     0s
#    4   1.00000000e+00 -1.01438094e+00  1.28e+00 4.80e-04  1.07e-01     0s
#    5   1.00000000e+00  6.79472215e-01  1.75e-01 2.08e-05  1.35e-02     0s
#    6   1.00000000e+00  9.18623916e-01  1.92e-07 7.68e-07  1.45e-03     0s
#    7   1.00000000e+00  9.99883941e-01  6.33e-11 8.95e-10  2.07e-06     0s
#    8   1.00000000e+00  9.99999872e-01  6.36e-14 9.84e-13  2.28e-09     0s
#
# Barrier solved model in 8 iterations and 0.03 seconds (0.00 work units)
# Optimal objective 1.00000000e+00
#
# Slave model solution:
# p_z_up : Size=18, Index=LC
#     Key       : Lower : Value               : Upper : Fixed : Stale : Domain
#     (0, 0, 1) :  None :  0.8912471382324344 :  None : False : False :  Reals
#     (0, 1, 0) :  None :                 0.0 :  None : False : False :  Reals
#     (1, 1, 2) :  None : 0.37406585404001685 :  None : False : False :  Reals
#     (1, 2, 1) :  None :                 0.0 :  None : False : False :  Reals
#     (2, 1, 3) :  None : 0.36806259320653256 :  None : False : False :  Reals
#     (2, 3, 1) :  None :                 0.0 :  None : False : False :  Reals
#     (3, 2, 4) :  None :   0.108440493923743 :  None : False : False :  Reals
#     (3, 4, 2) :  None :                 0.0 :  None : False : False :  Reals
#     (4, 2, 5) :  None :  0.1280243825922094 :  None : False : False :  Reals
#     (4, 5, 2) :  None :                 0.0 :  None : False : False :  Reals
#     (5, 5, 6) :  None :                 0.0 :  None : False : False :  Reals
#     (5, 6, 5) :  None :                 0.0 :  None : False : False :  Reals
#     (6, 3, 6) :  None : 0.20378856731488937 :  None : False : False :  Reals
#     (6, 6, 3) :  None :                 0.0 :  None : False : False :  Reals
#     (7, 4, 7) :  None :                 0.0 :  None : False : False :  Reals
#     (7, 7, 4) :  None :                 0.0 :  None : False : False :  Reals
#     (8, 6, 7) :  None : 0.06840454125357232 :  None : False : False :  Reals
#     (8, 7, 6) :  None :                 0.0 :  None : False : False :  Reals
# p_z_dn : Size=18, Index=LC
#     Key       : Lower : Value                : Upper : Fixed : Stale : Domain
#     (0, 0, 1) :  None :  -0.8421284472465452 :  None : False : False :  Reals
#     (0, 1, 0) :  None :                 -0.0 :  None : False : False :  Reals
#     (1, 1, 2) :  None :  -0.3564648765159402 :  None : False : False :  Reals
#     (1, 2, 1) :  None :                  0.0 :  None : False : False :  Reals
#     (2, 1, 3) :  None :   -0.353788567314887 :  None : False : False :  Reals
#     (2, 3, 1) :  None :                  0.0 :  None : False : False :  Reals
#     (3, 2, 4) :  None :                -0.08 :  None : False : False :  Reals
#     (3, 4, 2) :  None :                  0.0 :  None : False : False :  Reals
#     (4, 2, 5) :  None :                 -0.1 :  None : False : False :  Reals
#     (4, 5, 2) :  None :                  0.0 :  None : False : False :  Reals
#     (5, 5, 6) :  None :                  0.0 :  None : False : False :  Reals
#     (5, 6, 5) :  None :                  0.0 :  None : False : False :  Reals
#     (6, 3, 6) :  None : -0.18840454125357187 :  None : False : False :  Reals
#     (6, 6, 3) :  None :                  0.0 :  None : False : False :  Reals
#     (7, 4, 7) :  None :                  0.0 :  None : False : False :  Reals
#     (7, 7, 4) :  None :                  0.0 :  None : False : False :  Reals
#     (8, 6, 7) :  None :                -0.06 :  None : False : False :  Reals
#     (8, 7, 6) :  None :                  0.0 :  None : False : False :  Reals
# i_sq : Size=18, Index=LC
#     Key       : Lower : Value               : Upper : Fixed : Stale : Domain
#     (0, 0, 1) :     0 :   4.911869098588293 :  None : False : False : NonNegativeReals
#     (0, 1, 0) :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     (1, 1, 2) :     0 :  0.8800488762040547 :  None : False : False : NonNegativeReals
#     (1, 2, 1) :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     (2, 1, 3) :     0 :    0.71370129458256 :  None : False : False : NonNegativeReals
#     (2, 3, 1) :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     (3, 2, 4) :     0 :  0.9480164641246606 :  None : False : False : NonNegativeReals
#     (3, 4, 2) :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     (4, 2, 5) :     0 :   0.934146086407042 :  None : False : False : NonNegativeReals
#     (4, 5, 2) :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     (5, 5, 6) :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     (5, 6, 5) :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     (6, 3, 6) :     0 :  0.7692013030656745 :  None : False : False : NonNegativeReals
#     (6, 6, 3) :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     (7, 4, 7) :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     (7, 7, 4) :     0 :                 0.0 :  None : False : False : NonNegativeReals
#     (8, 6, 7) :     0 : 0.21011353133931132 :  None : False : False : NonNegativeReals
#     (8, 7, 6) :     0 :                 0.0 :  None : False : False : NonNegativeReals
# q_z_up : Size=18, Index=LC
#     Key       : Lower : Value               : Upper : Fixed : Stale : Domain
#     (0, 0, 1) :  None :   1.089973153752327 :  None : False : False :  Reals
#     (0, 1, 0) :  None :                 0.0 :  None : False : False :  Reals
#     (1, 1, 2) :  None :  0.3861574976573301 :  None : False : False :  Reals
#     (1, 2, 1) :  None :                 0.0 :  None : False : False :  Reals
#     (2, 1, 3) :  None :  0.3396273410139149 :  None : False : False :  Reals
#     (2, 3, 1) :  None :                 0.0 :  None : False : False :  Reals
#     (3, 2, 4) :  None : 0.10878541073445322 :  None : False : False :  Reals
#     (3, 4, 2) :  None :                 0.0 :  None : False : False :  Reals
#     (4, 2, 5) :  None : 0.11798478534530064 :  None : False : False :  Reals
#     (4, 5, 2) :  None :                 0.0 :  None : False : False :  Reals
#     (5, 5, 6) :  None :                 0.0 :  None : False : False :  Reals
#     (5, 6, 5) :  None :                 0.0 :  None : False : False :  Reals
#     (6, 3, 6) :  None : 0.21880512357579088 :  None : False : False :  Reals
#     (6, 6, 3) :  None :                 0.0 :  None : False : False :  Reals
#     (7, 4, 7) :  None :                 0.0 :  None : False : False :  Reals
#     (7, 7, 4) :  None :                 0.0 :  None : False : False :  Reals
#     (8, 6, 7) :  None : 0.07320874201554667 :  None : False : False :  Reals
#     (8, 7, 6) :  None :                 0.0 :  None : False : False :  Reals
# q_z_dn : Size=18, Index=LC
#     Key       : Lower : Value                 : Upper : Fixed : Stale : Domain
#     (0, 0, 1) :  None :     -0.84437969882292 :  None : False : False :  Reals
#     (0, 1, 0) :  None :                  -0.0 :  None : False : False :  Reals
#     (1, 1, 2) :  None :  -0.35095554260915723 :  None : False : False :  Reals
#     (1, 2, 1) :  None :                   0.0 :  None : False : False :  Reals
#     (2, 1, 3) :  None :    -0.311079289230603 :  None : False : False :  Reals
#     (2, 3, 1) :  None :                   0.0 :  None : False : False :  Reals
#     (3, 2, 4) :  None : -0.061384587528191314 :  None : False : False :  Reals
#     (3, 4, 2) :  None :                   0.0 :  None : False : False :  Reals
#     (4, 2, 5) :  None :  -0.07127748102491964 :  None : False : False :  Reals
#     (4, 5, 2) :  None :                   0.0 :  None : False : False :  Reals
#     (5, 5, 6) :  None :                   0.0 :  None : False : False :  Reals
#     (5, 6, 5) :  None :                   0.0 :  None : False : False :  Reals
#     (6, 3, 6) :  None :  -0.19572908448383775 :  None : False : False :  Reals
#     (6, 6, 3) :  None :                   0.0 :  None : False : False :  Reals
#     (7, 4, 7) :  None :                   0.0 :  None : False : False :  Reals
#     (7, 7, 4) :  None :                   0.0 :  None : False : False :  Reals
#     (8, 6, 7) :  None : -0.060601930135194645 :  None : False : False :  Reals
#     (8, 7, 6) :  None :                   0.0 :  None : False : False :  Reals

# %%
import networkx as nx
import matplotlib.pyplot as plt
from collections import deque
import pyomo.environ as pyo

def tree_layout(G, root=0):
    """Generate a tree-like layout using a breadth-first search from the root."""
    UG = G.to_undirected()
    queue = deque([root])
    visited = {root}
    level = {root: 0}
    while queue:
        u = queue.popleft()
        for v in UG[u]:
            if v not in visited:
                visited.add(v)
                level[v] = level[u] + 1
                queue.append(v)
    level_dict = {}
    for node, lv in level.items():
        level_dict.setdefault(lv, []).append(node)
    pos = {}
    for lv, nodes in level_dict.items():
        offset = -(len(nodes)-1)/2.0
        for i, node in enumerate(nodes):
            pos[node] = (lv, i + offset)
    return pos

# %%
def plot_solution_with_switch_status(instance):
    """
    Plots the reconfigured network using the solution from the master model.

    This version uses the candidate set model.LF (which is a set of tuples (l, i, j)).
    For each line l, the function finds the candidate (i,j) in instance.LF with l as its first element
    that is active (i.e., instance.d[l, i, j] >= 0.5) if possible. If the line is switchable and the switch
    is open (instance.z[l] < 0.5), a default candidate is chosen (here, the first candidate in instance.F[l]).
    """
    closed_switch_edges = []
    open_switch_edges = []
    non_switchable_edges = []
    edge_labels = {}

    # Loop over each line in the network
    for l in instance.L:
        effective_edge = None
        # Look for an active candidate for line l.
        for (l_candidate, i, j) in instance.LF:
            if l_candidate != l:
                continue
            d_val = pyo.value(instance.d[l_candidate, i, j])
            if d_val is not None and d_val >= 0.5:
                effective_edge = (i, j)
                break
        
        # If no candidate is active and the line is switchable (and supposed to be open),
        # use a default candidate (e.g., the first candidate from instance.F[l]).
        if effective_edge is None and l in instance.S:
            # Pick the first candidate from instance.F[l] as default
            # (Assuming instance.F[l] is a tuple or list; adjust accordingly)
            default_candidate = list(instance.F[l])[0]
            effective_edge = default_candidate

        # If still no candidate is found (for non-switchable lines, this should not happen), skip.
        if effective_edge is None:
            continue

        edge_labels[effective_edge] = f"L{l}"
        
        if l in instance.S:
            # For switchable lines, determine status using the switch variable.
            z_val = pyo.value(instance.Delta[l])
            if z_val is not None and z_val >= 0.5:
                closed_switch_edges.append(effective_edge)
            else:
                open_switch_edges.append(effective_edge)
        else:
            non_switchable_edges.append(effective_edge)

    # Create a directed graph for visualization
    G_all = nx.DiGraph()
    for node in instance.I:
        G_all.add_node(node)
    for edge in closed_switch_edges + open_switch_edges + non_switchable_edges:
        G_all.add_edge(*edge)
    
    pos = tree_layout(G_all, root=0)
    
    plt.figure(figsize=(8, 6))
    nx.draw_networkx_nodes(G_all, pos, node_size=800, node_color='lightblue')
    nx.draw_networkx_labels(G_all, pos)
    
    # Draw edges with different styles based on the switch status.
    nx.draw_networkx_edges(G_all, pos, edgelist=closed_switch_edges,
                           edge_color='blue', arrows=True, width=2, label='Closed Switch')
    nx.draw_networkx_edges(G_all, pos, edgelist=open_switch_edges,
                           edge_color='red', style='dashed', arrows=True, width=2, label='Open Switch')
    nx.draw_networkx_edges(G_all, pos, edgelist=non_switchable_edges,
                           edge_color='green', arrows=True, width=2, label='Non-Switchable')
    
    nx.draw_networkx_edge_labels(G_all, pos, edge_labels=edge_labels, font_color='purple')
    
    plt.title("Reconfigured Network\nBlue: Closed Switch, Red Dashed: Open Switch, Green: Non-Switchable")
    plt.axis('off')
    plt.legend(scatterpoints=1)
    plt.show()


# Example usage:
# After solving the master_model instance (e.g., master_instance),
# call:
plot_solution_with_switch_status(master_instance)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 83
#      77     plt.show()
#      80 # Example usage:
#      81 # After solving the master_model instance (e.g., master_instance),
#      82 # call:
# ---> 83 plot_solution_with_switch_status(master_instance)
#
# Cell In[8], line 19, in plot_solution_with_switch_status(instance)
#      17 effective_edge = None
#      18 # Look for an active candidate for line l.
# ---> 19 for (l_candidate, i, j) in instance.LF:
#      20     if l_candidate != l:
#      21         continue
#
# File ~/github/dig-a-plan-optimization/.venv/lib/python3.12/site-packages/pyomo/core/base/block.py:550, in BlockData.__getattr__(self, val)
#     547     return _component_decorator(self, ModelComponentFactory.get_class(val))
#     548 # Since the base classes don't support getattr, we can just
#     549 # throw the "normal" AttributeError
# --> 550 raise AttributeError(
#     551     "'%s' object has no attribute '%s'" % (self.__class__.__name__, val)
#     552 )
#
# AttributeError: 'ConcreteModel' object has no attribute 'LF'
